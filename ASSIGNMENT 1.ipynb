# %% [markdown]
# # Assignment #01 - Python for Data Science#

# %% [markdown]
# #   Read the given dataset to python environment.

# %%
#import libraries
import pandas  as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
#import dataset
data=pd.read_excel(r"/home/dell/Downloads/iris.xls")
data
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    NaN  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  NaN  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# #  Display the columns in the dataset.

# %%
#column headings in the dataset
data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# #  Calculate the mean of each column of the dataset.

# %%
#mean value of SL
data["SL"].mean()
# Out:
# 5.8559440559440565

# %%
#mean value of SW
data["SW"].mean()
# Out:
# 3.0493055555555566

# %%
#mean value of PL
data["PL"].mean()
# Out:
# 3.756250000000003

# %%
#mean value ofPW
data["PW"].mean()
# Out:
# 1.1986666666666672

# %%
print("mean value of SL = 5.8559440559440565")
print("mean value of SW = 3.0493055555555566")
print("mean value of PL = 3.756250000000003")
print("mean value of PW = 1.1986666666666672")
# Out:
# mean value of SL = 5.8559440559440565
# mean value of SW = 3.0493055555555566
# mean value of PL = 3.756250000000003
# mean value of PW = 1.1986666666666672

# %% [markdown]
# #  Check for the null values present in the dataset.

# %%
# checking for null values in the data set
data.isna().sum()
# Out:
# SL                7
# SW                6
# PL                6
# PW                0
# Classification    0
# dtype: int64

# %%
# 7 null values present in "SL"
#6 null values present in both "SW"&"PL"

# %% [markdown]
# #   Perform meaningful visualizations using the dataset. Bring at least 3 visualizations.

# %%
#histogram of SL &SW
data[["SL","SW"]].plot.hist()
plt.title("SL & SW")
plt.show()

# %%
#Boxplot for iris-setosa
data.iloc[[0,49]]
plt.figure(figsize = (10, 7))
plt.title("iris-setosa")

data.boxplot()
# Out:
# <AxesSubplot:title={'center':'iris-setosa'}>

# %%
sns.pairplot(data)
